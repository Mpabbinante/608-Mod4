# %%
#https://poestories.com/read/eldorado

# %%
# fig06_02.py
"""Tokenizing a string and counting unique words."""

text = ('GAILY bedight, A gallant knight In sunshine and in shadow,Had journeyed longSinging a songIn search of Eldorado.' 'but he grew old -- This knight so bold --And oer his heart a shadowFell as he foundNo spot of ground That looked like Eldorado.'

       ' And, as his strength'
        'Failed him at length,'
'He met a pilgrim shadow --'
        ',Shadow, said he,'
        'Where can it be --'
'This land of Eldorado?"'

       '"Over the Mountains'
       ' Of the Moon,'
'Down the Valley of the Shadow,'
     '   Ride, boldly ride,'
       'The shade replied, --'
'If you seek for Eldorado!')

word_counts = {}

# count occurrences of each unique word
for word in text.split():
    if word in word_counts: 
        word_counts[word] += 1  # update existing key-value pair
    else:
        word_counts[word] = 1  # insert new key-value pair

print(f'{"WORD":<12}COUNT')

for word, count in sorted(word_counts.items()):
    print(f'{word:<12}{count}')

print('\nNumber of unique words:', len(word_counts))
# Out:
# WORD        COUNT
# --          1
# --,Shadow,  1
# --And       1
# --If        1
# --This      1
# A           1
# And,        1
# Eldorado!   1
# Eldorado.   1
# Eldorado.but1
# Eldorado?""Over1
# GAILY       1
# In          1
# Moon,Down   1
# Mountains   1
# Of          1
# Ride,       1
# Shadow,     1
# That        1
# This        1
# Valley      1
# a           3
# and         1
# as          2
# at          1
# be          1
# bedight,    1
# bold        1
# boldly      1
# can         1
# for         1
# foundNo     1
# gallant     1
# grew        1
# ground      1
# he          2
# he,Where    1
# heart       1
# him         1
# his         2
# in          1
# it          1
# journeyed   1
# knight      2
# land        1
# length,He   1
# like        1
# longSinging 1
# looked      1
# met         1
# oer         1
# of          4
# old         1
# pilgrim     1
# replied,    1
# ride,The    1
# said        1
# search      1
# seek        1
# shade       1
# shadow      1
# ...

# %%
#Mike Abbinante
